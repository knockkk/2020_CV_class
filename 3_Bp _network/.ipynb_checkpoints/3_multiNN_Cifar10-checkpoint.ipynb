# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

from data_utils import load_CIFAR10
from MultilayerNN import BPNetWork

# %%
def pre_dataset():
    cifar10_dir = 'D:/dataset/cifar-10-python/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    #像素去均值化
    X_train = X_train - np.mean(X_train,axis=0)
    X_test = X_test - np.mean(X_test,axis=0)
    
    num_train = 2000
    num_test = 2000
    X_train = X_train[:num_train]
    y_train = y_train[:num_train]
    X_test = X_test[:num_test]
    y_test = y_test[:num_test]
    
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))

    # add a parameter for W
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])

    return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = pre_dataset()
# Out:
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_1
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_2
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_3
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_4
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_5
# D:/dataset/cifar-10-python/cifar-10-batches-py\test_batch

# %%
bp_network = BPNetWork()
bp_network.train(X_train,y_train,learning_rate=0.01,batch_num=300,
                 num_iter=2000,reg=0, dim1=50, dim2=50)
# Out:
# Iteration 0 / 2000, learning rate 0.005000 , loss 690.776818
# Iteration 500 / 2000, learning rate 0.005000 , loss 584.500529
# Iteration 1000 / 2000, learning rate 0.005000 , loss 510.890328
# Iteration 1500 / 2000, learning rate 0.002500 , loss 423.756181

# %%
#accuracy in train dataset and test dataset
y_pred = bp_network.predict(X_test)
print('acc in testSet:',np.mean(y_pred == y_test))

y_pred = bp_network.predict(X_train)
print('acc in trainSet:',np.mean(y_pred == y_train))
# Out:
# acc in testSet: 0.2125
# acc in trainSet: 0.576

# %%
bp_network = BPNetWork()
bp_network.train(X_train,y_train,learning_rate=0.01,batch_num=300,
                 num_iter=2000,reg=0.001, dim1=50, dim2=50)
# Out:
# Iteration 0 / 2000, learning rate 0.005000 , loss 690.773688
# Iteration 500 / 2000, learning rate 0.005000 , loss 548.844382
# Iteration 1000 / 2000, learning rate 0.005000 , loss 479.792208
# Iteration 1500 / 2000, learning rate 0.002500 , loss 423.941616

# %%
#accuracy in train dataset and test dataset
y_pred = bp_network.predict(X_test)
print('acc in testSet:',np.mean(y_pred == y_test))

y_pred = bp_network.predict(X_train)
print('acc in trainSet:',np.mean(y_pred == y_train))
# Out:
# acc in testSet: 0.1885
# acc in trainSet: 0.5195
