# %% [markdown]
# ##### 1. 数据归一化：意义
#
# min-max归一化

# %%
import numpy as np
from data_utils import load_CIFAR10
from softmax_without_regression import Softmax
import matplotlib.pyplot as plt

# %%
def min_max_scaler(X):
    min1 = 0
    max1 = 255
    return (X-min1)/(max1-min1)

# %%
def pre_dataset():
    cifar10_dir = 'D:/dataset/cifar-10-python/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    num_train = 48000
    num_val = 2000

    mask = range(num_train, num_train + num_val)
    X_val = X_train[mask]
    y_val = y_train[mask]
    X_train = X_train[:num_train]
    y_train = y_train[:num_train]

    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))

    X_train = min_max_scaler(X_train)
    X_val = min_max_scaler(X_val)
    X_test = min_max_scaler(X_test)

    # add a parameter for W
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])

    return X_train, y_train, X_test, y_test, X_val, y_val

# %%
def get_softmax_model(X, y,learning_rate,batch_num,num_iter):
    softmax = Softmax()
    loss_history = softmax.train(X, y, learning_rate,batch_num,num_iter)
    VisualizeLoss(loss_history)
    return softmax

def VisualizeLoss(loss_history):
    plt.plot(loss_history)
    plt.xlabel('Iteration number')
    plt.ylabel('Loss value')
    plt.show()

# %% [markdown]
# ##### batch_num探究：learning_rate=0.01;num_iter=2000; 变化batch_num

# %%
X_train, y_train, X_test, y_test, X_val, y_val = pre_dataset()
batch_nums = [200,300,500,1000,1500]
learning_rates = [1e-2,1e-3,1e-4]
num_iter = 2000
for learning_rate in learning_rates:
    for batch_num in batch_nums:
        softmax = get_softmax_model(X_train, y_train,learning_rate,batch_num,num_iter)
        y_pred = softmax.predict(X_test)
        acc = np.mean(y_pred == y_test)
        print('learning_rate: %f;batch_num: %d; Accuracy: %f' % (learning_rate,batch_num,acc))
# Out:
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_1
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_2
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_3
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_4
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_5
# D:/dataset/cifar-10-python/cifar-10-batches-py\test_batch
# Iteration 0 / 2000: loss 2.305316
# Iteration 500 / 2000: loss 2.020009
# Iteration 1000 / 2000: loss 1.961072
# Iteration 1500 / 2000: loss 1.938286
# learning_rate: 0.010000;batch_num: 200; Accuracy: 0.302900
# Iteration 0 / 2000: loss 2.304450
# Iteration 500 / 2000: loss 2.021323
# Iteration 1000 / 2000: loss 1.971741
# Iteration 1500 / 2000: loss 1.986843
# learning_rate: 0.010000;batch_num: 300; Accuracy: 0.318300
# Iteration 0 / 2000: loss 2.300555
# Iteration 500 / 2000: loss 2.002993
# Iteration 1000 / 2000: loss 1.959004
# Iteration 1500 / 2000: loss 1.881957
# learning_rate: 0.010000;batch_num: 500; Accuracy: 0.343300
# Iteration 0 / 2000: loss 2.302710
# Iteration 500 / 2000: loss 1.975129
# Iteration 1000 / 2000: loss 1.927740
# Iteration 1500 / 2000: loss 1.902238
# learning_rate: 0.010000;batch_num: 1000; Accuracy: 0.342500
# Iteration 0 / 2000: loss 2.303751
# Iteration 500 / 2000: loss 1.995383
# Iteration 1000 / 2000: loss 1.930251
# Iteration 1500 / 2000: loss 1.885611
# learning_rate: 0.010000;batch_num: 1500; Accuracy: 0.353300
# Iteration 0 / 2000: loss 2.302372
# Iteration 500 / 2000: loss 2.209459
# Iteration 1000 / 2000: loss 2.148354
# Iteration 1500 / 2000: loss 2.094332
# learning_rate: 0.001000;batch_num: 200; Accuracy: 0.286800
# Iteration 0 / 2000: loss 2.304716
# Iteration 500 / 2000: loss 2.217378
# Iteration 1000 / 2000: loss 2.178892
# Iteration 1500 / 2000: loss 2.151505
# learning_rate: 0.001000;batch_num: 300; Accuracy: 0.281100
# Iteration 0 / 2000: loss 2.302370
# Iteration 500 / 2000: loss 2.215828
# Iteration 1000 / 2000: loss 2.151008
# Iteration 1500 / 2000: loss 2.126789
# learning_rate: 0.001000;batch_num: 500; Accuracy: 0.307000
# Iteration 0 / 2000: loss 2.302971
# Iteration 500 / 2000: loss 2.225842
# Iteration 1000 / 2000: loss 2.155148
# Iteration 1500 / 2000: loss 2.121632
# learning_rate: 0.001000;batch_num: 1000; Accuracy: 0.290700
# Iteration 0 / 2000: loss 2.303808
# Iteration 500 / 2000: loss 2.219489
# Iteration 1000 / 2000: loss 2.162309
# Iteration 1500 / 2000: loss 2.120793
# learning_rate: 0.001000;batch_num: 1500; Accuracy: 0.298400
# Iteration 0 / 2000: loss 2.301014
# Iteration 500 / 2000: loss 2.292746
# Iteration 1000 / 2000: loss 2.279679
# Iteration 1500 / 2000: loss 2.269117
# learning_rate: 0.000100;batch_num: 200; Accuracy: 0.282700
# Iteration 0 / 2000: loss 2.303258
# Iteration 500 / 2000: loss 2.297559
# Iteration 1000 / 2000: loss 2.279327
# Iteration 1500 / 2000: loss 2.272082
# learning_rate: 0.000100;batch_num: 300; Accuracy: 0.241300
# Iteration 0 / 2000: loss 2.303721
# Iteration 500 / 2000: loss 2.293994
# Iteration 1000 / 2000: loss 2.278094
# Iteration 1500 / 2000: loss 2.273219
# learning_rate: 0.000100;batch_num: 500; Accuracy: 0.227500
# Iteration 0 / 2000: loss 2.302994
# Iteration 500 / 2000: loss 2.292911
# Iteration 1000 / 2000: loss 2.283549
# Iteration 1500 / 2000: loss 2.270661
# learning_rate: 0.000100;batch_num: 1000; Accuracy: 0.221000
# Iteration 0 / 2000: loss 2.303132
# Iteration 500 / 2000: loss 2.293707
# Iteration 1000 / 2000: loss 2.282640
# Iteration 1500 / 2000: loss 2.274545
# learning_rate: 0.000100;batch_num: 1500; Accuracy: 0.217200
# Iteration 0 / 2000: loss 2.301963
# Iteration 500 / 2000: loss 2.300036
# Iteration 1000 / 2000: loss 2.302501
# Iteration 1500 / 2000: loss 2.298876
# learning_rate: 0.000010;batch_num: 200; Accuracy: 0.100300
# Iteration 0 / 2000: loss 2.302399
# Iteration 500 / 2000: loss 2.302106
# Iteration 1000 / 2000: loss 2.299655
# Iteration 1500 / 2000: loss 2.297423
# learning_rate: 0.000010;batch_num: 300; Accuracy: 0.107600
# Iteration 0 / 2000: loss 2.303719
# Iteration 500 / 2000: loss 2.301727
# Iteration 1000 / 2000: loss 2.298704
# Iteration 1500 / 2000: loss 2.299195
# learning_rate: 0.000010;batch_num: 500; Accuracy: 0.100600
# Iteration 0 / 2000: loss 2.304728
# Iteration 500 / 2000: loss 2.301272
# Iteration 1000 / 2000: loss 2.300803
# Iteration 1500 / 2000: loss 2.298729
# learning_rate: 0.000010;batch_num: 1000; Accuracy: 0.100700
# Iteration 0 / 2000: loss 2.303653
# Iteration 500 / 2000: loss 2.301611
# Iteration 1000 / 2000: loss 2.299794
# Iteration 1500 / 2000: loss 2.299205
# learning_rate: 0.000010;batch_num: 1500; Accuracy: 0.100000
# Iteration 0 / 2000: loss 2.298779
# Iteration 500 / 2000: loss 2.305292
# Iteration 1000 / 2000: loss 2.307178
# Iteration 1500 / 2000: loss 2.302883
# learning_rate: 0.000001;batch_num: 200; Accuracy: 0.085700
# Iteration 0 / 2000: loss 2.300213
# Iteration 500 / 2000: loss 2.305951
# Iteration 1000 / 2000: loss 2.308387
# Iteration 1500 / 2000: loss 2.302672
# learning_rate: 0.000001;batch_num: 300; Accuracy: 0.100000
# Iteration 0 / 2000: loss 2.302452
# Iteration 500 / 2000: loss 2.301540
# Iteration 1000 / 2000: loss 2.303264
# Iteration 1500 / 2000: loss 2.304110
# learning_rate: 0.000001;batch_num: 500; Accuracy: 0.100000
# Iteration 0 / 2000: loss 2.303395
# Iteration 500 / 2000: loss 2.301783
# Iteration 1000 / 2000: loss 2.302983
# Iteration 1500 / 2000: loss 2.302863
# learning_rate: 0.000001;batch_num: 1000; Accuracy: 0.100000
# Iteration 0 / 2000: loss 2.303052
# Iteration 500 / 2000: loss 2.304075
# Iteration 1000 / 2000: loss 2.301658
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f58de197726f> in <module>
#       5 for learning_rate in learning_rates:
#       6     for batch_num in batch_nums:
# ----> 7         softmax = get_softmax_model(X_train, y_train,learning_rate,batch_num,num_iter)
#       8         y_pred = softmax.predict(X_test)
#       9         acc = np.mean(y_pred == y_test)
#
# <ipython-input-4-cb8fbdffb963> in get_softmax_model(X, y, learning_rate, batch_num, num_iter)
#       1 def get_softmax_model(X, y,learning_rate,batch_num,num_iter):
#       2     softmax = Softmax()
# ----> 3     loss_history = softmax.train(X, y, learning_rate,batch_num,num_iter)
#       4     VisualizeLoss(loss_history)
#       5     return softmax
#
# E:\2020种子班课程\计算机视觉\code\Softmax_clf\softmax_cifar10_281\softmax_without_regression.py in train(self, X, y, learning_rate, batch_num, num_iter)
#      22             y_batch = y[sample_index]
#      23
# ---> 24             loss, gred = self.softmax_cost_function(X_batch, y_batch)
#      25             loss_history.append(loss)
#      26
#
# E:\2020种子班课程\计算机视觉\code\Softmax_clf\softmax_cifar10_281\softmax_without_regression.py in softmax_cost_function(self, X, y)
#      43         # X: N * D, y: N
#      44         num_train = X.shape[0]
# ---> 45         scores = X.dot(self.W.T)
#      46         exp_scores = np.exp(scores)  # N * C
#      47         pro_scores = (exp_scores / np.matrix(np.sum(exp_scores, axis=1)).T).getA()
#
# KeyboardInterrupt:
