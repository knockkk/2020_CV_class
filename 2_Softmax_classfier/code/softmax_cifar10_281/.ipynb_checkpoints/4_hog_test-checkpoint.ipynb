# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from skimage.feature import hog
from skimage import io

from data_utils import load_CIFAR10_raw
from softmax_without_regression import Softmax


def pre_dataset():
    cifar10_dir = 'D:/dataset/cifar-10-python/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10_raw(cifar10_dir)
    train_num = 20000
    test_num = 5000
    X_train = X_train[0:train_num]
    y_train = y_train[0:train_num]
    X_test = X_test[0:test_num]
    y_test = y_test[0:test_num]
    # 提取hog特征
    X_train_hog = []
    for i in range(X_train.shape[0]):
        curr_features = hog(X_train[i], orientations=9, pixels_per_cell=(4, 4),
                            cells_per_block=(2, 2), visualize=False)
        X_train_hog.append(curr_features)
        if(i % 100 == 0):
            print('hog processing train_data %d' % i)
    X_train_hog = np.array(X_train_hog)

    X_test_hog = []
    for i in range(X_test.shape[0]):
        curr_features = hog(X_test[i], orientations=9, pixels_per_cell=(4, 4),
                            cells_per_block=(2, 2), visualize=False)
        X_test_hog.append(curr_features)
        if(i % 100 == 0):
            print('hog processing test data %d' % i)
    X_test_hog = np.array(X_test_hog)

    # add a parameter for W
    X_train = np.hstack([X_train_hog, np.ones((X_train.shape[0], 1))])
    X_test = np.hstack([X_test_hog, np.ones((X_test.shape[0], 1))])

    return X_train, y_train, X_test, y_test


def get_softmax_model(X, y, learning_rate, batch_num, num_iter):
    softmax = Softmax()
    loss_history = softmax.train(X, y, learning_rate, batch_num, num_iter)
    VisualizeLoss(loss_history)
    return softmax


def VisualizeLoss(loss_history):
    plt.plot(loss_history)
    plt.xlabel('Iteration number')
    plt.ylabel('Loss value')
    plt.show()


def pca_dim_reduction(X_train,X_test): #降维
    pca = PCA(n_components=128)
    pca.fit(X_train)
    X_train_transformed = pca.transform(X_train)
    X_test_transformed = pca.transform(X_test)
    return X_train_transformed,X_test_transformed

# %%
X_train, y_train, X_test, y_test = pre_dataset()
# Out:
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_1
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_2
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_3
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_4
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_5
# D:/dataset/cifar-10-python/cifar-10-batches-py\test_batch
# hog processing train_data 0
# hog processing train_data 100
# hog processing train_data 200
# hog processing train_data 300
# hog processing train_data 400
# hog processing train_data 500
# hog processing train_data 600
# hog processing train_data 700
# hog processing train_data 800
# hog processing train_data 900
# hog processing train_data 1000
# hog processing train_data 1100
# hog processing train_data 1200
# hog processing train_data 1300
# hog processing train_data 1400
# hog processing train_data 1500
# hog processing train_data 1600
# hog processing train_data 1700
# hog processing train_data 1800
# hog processing train_data 1900
# hog processing train_data 2000
# hog processing train_data 2100
# hog processing train_data 2200
# hog processing train_data 2300
# hog processing train_data 2400
# hog processing train_data 2500
# hog processing train_data 2600
# hog processing train_data 2700
# hog processing train_data 2800
# hog processing train_data 2900
# hog processing train_data 3000
# hog processing train_data 3100
# hog processing train_data 3200
# hog processing train_data 3300
# hog processing train_data 3400
# hog processing train_data 3500
# hog processing train_data 3600
# hog processing train_data 3700
# hog processing train_data 3800
# hog processing train_data 3900
# hog processing train_data 4000
# hog processing train_data 4100
# hog processing train_data 4200
# hog processing train_data 4300
# hog processing train_data 4400
# hog processing train_data 4500
# hog processing train_data 4600
# hog processing train_data 4700
# hog processing train_data 4800
# hog processing train_data 4900
# hog processing train_data 5000
# hog processing train_data 5100
# hog processing train_data 5200
# hog processing train_data 5300
# hog processing train_data 5400
# hog processing train_data 5500
# hog processing train_data 5600
# hog processing train_data 5700
# hog processing train_data 5800
# hog processing train_data 5900
# hog processing train_data 6000
# hog processing train_data 6100
# hog processing train_data 6200
# hog processing train_data 6300
# hog processing train_data 6400
# hog processing train_data 6500
# hog processing train_data 6600
# hog processing train_data 6700
# hog processing train_data 6800
# hog processing train_data 6900
# hog processing train_data 7000
# hog processing train_data 7100
# hog processing train_data 7200
# hog processing train_data 7300
# hog processing train_data 7400
# hog processing train_data 7500
# hog processing train_data 7600
# hog processing train_data 7700
# hog processing train_data 7800
# hog processing train_data 7900
# hog processing train_data 8000
# hog processing train_data 8100
# hog processing train_data 8200
# hog processing train_data 8300
# hog processing train_data 8400
# hog processing train_data 8500
# hog processing train_data 8600
# hog processing train_data 8700
# hog processing train_data 8800
# hog processing train_data 8900
# hog processing train_data 9000
# hog processing train_data 9100
# hog processing train_data 9200
# hog processing train_data 9300
# hog processing train_data 9400
# hog processing train_data 9500
# hog processing train_data 9600
# hog processing train_data 9700
# hog processing train_data 9800
# hog processing train_data 9900
# hog processing train_data 10000
# hog processing train_data 10100
# hog processing train_data 10200
# hog processing train_data 10300
# hog processing train_data 10400
# hog processing train_data 10500
# hog processing train_data 10600
# hog processing train_data 10700
# hog processing train_data 10800
# hog processing train_data 10900
# hog processing train_data 11000
# hog processing train_data 11100
# hog processing train_data 11200
# hog processing train_data 11300
# hog processing train_data 11400
# hog processing train_data 11500
# hog processing train_data 11600
# hog processing train_data 11700
# hog processing train_data 11800
# hog processing train_data 11900
# hog processing train_data 12000
# hog processing train_data 12100
# hog processing train_data 12200
# hog processing train_data 12300
# hog processing train_data 12400
# hog processing train_data 12500
# hog processing train_data 12600
# hog processing train_data 12700
# hog processing train_data 12800
# hog processing train_data 12900
# hog processing train_data 13000
# hog processing train_data 13100
# hog processing train_data 13200
# hog processing train_data 13300
# hog processing train_data 13400
# hog processing train_data 13500
# hog processing train_data 13600
# hog processing train_data 13700
# hog processing train_data 13800
# hog processing train_data 13900
# hog processing train_data 14000
# hog processing train_data 14100
# hog processing train_data 14200
# hog processing train_data 14300
# hog processing train_data 14400
# hog processing train_data 14500
# hog processing train_data 14600
# hog processing train_data 14700
# hog processing train_data 14800
# hog processing train_data 14900
# hog processing train_data 15000
# hog processing train_data 15100
# hog processing train_data 15200
# hog processing train_data 15300
# hog processing train_data 15400
# hog processing train_data 15500
# hog processing train_data 15600
# hog processing train_data 15700
# hog processing train_data 15800
# hog processing train_data 15900
# hog processing train_data 16000
# hog processing train_data 16100
# hog processing train_data 16200
# hog processing train_data 16300
# hog processing train_data 16400
# hog processing train_data 16500
# hog processing train_data 16600
# hog processing train_data 16700
# hog processing train_data 16800
# hog processing train_data 16900
# hog processing train_data 17000
# hog processing train_data 17100
# hog processing train_data 17200
# hog processing train_data 17300
# hog processing train_data 17400
# hog processing train_data 17500
# hog processing train_data 17600
# hog processing train_data 17700
# hog processing train_data 17800
# hog processing train_data 17900
# hog processing train_data 18000
# hog processing train_data 18100
# hog processing train_data 18200
# hog processing train_data 18300
# hog processing train_data 18400
# hog processing train_data 18500
# hog processing train_data 18600
# hog processing train_data 18700
# hog processing train_data 18800
# hog processing train_data 18900
# hog processing train_data 19000
# hog processing train_data 19100
# hog processing train_data 19200
# hog processing train_data 19300
# hog processing train_data 19400
# hog processing train_data 19500
# hog processing train_data 19600
# hog processing train_data 19700
# hog processing train_data 19800
# hog processing train_data 19900
# hog processing test data 0
# hog processing test data 100
# hog processing test data 200
# hog processing test data 300
# hog processing test data 400
# hog processing test data 500
# hog processing test data 600
# hog processing test data 700
# hog processing test data 800
# hog processing test data 900
# hog processing test data 1000
# hog processing test data 1100
# hog processing test data 1200
# hog processing test data 1300
# hog processing test data 1400
# hog processing test data 1500
# hog processing test data 1600
# hog processing test data 1700
# hog processing test data 1800
# hog processing test data 1900
# hog processing test data 2000
# hog processing test data 2100
# hog processing test data 2200
# hog processing test data 2300
# hog processing test data 2400
# hog processing test data 2500
# hog processing test data 2600
# hog processing test data 2700
# hog processing test data 2800
# hog processing test data 2900
# hog processing test data 3000
# hog processing test data 3100
# hog processing test data 3200
# hog processing test data 3300
# hog processing test data 3400
# hog processing test data 3500
# hog processing test data 3600
# hog processing test data 3700
# hog processing test data 3800
# hog processing test data 3900
# hog processing test data 4000
# hog processing test data 4100
# hog processing test data 4200
# hog processing test data 4300
# hog processing test data 4400
# hog processing test data 4500
# hog processing test data 4600
# hog processing test data 4700
# hog processing test data 4800
# hog processing test data 4900

# %%
#pca降维
X_train,X_test = pca_dim_reduction(X_train,X_test)
print("reduction",X_train.shape)
# Out:
# reduction (20000, 128)

# %%
batch_nums = [500]
learning_rates = [0.001]
num_iter = 20000
for learning_rate in learning_rates:
    for batch_num in batch_nums:
        softmax = get_softmax_model(
            X_train, y_train, learning_rate, batch_num, num_iter)
        y_pred = softmax.predict(X_test)
        acc = np.mean(y_pred == y_test)
        print('learning_rate: %f;batch_num: %d; Accuracy: %f' %
              (learning_rate, batch_num, acc))
# Out:
# Iteration 0 / 10000: loss 2.302972
# Iteration 500 / 10000: loss 2.295531
# Iteration 1000 / 10000: loss 2.289207
# Iteration 1500 / 10000: loss 2.287157
# Iteration 2000 / 10000: loss 2.283200
# Iteration 2500 / 10000: loss 2.279647
# Iteration 3000 / 10000: loss 2.276190
# Iteration 3500 / 10000: loss 2.276833
# Iteration 4000 / 10000: loss 2.273111
# Iteration 4500 / 10000: loss 2.271068
# Iteration 5000 / 10000: loss 2.272643
# Iteration 5500 / 10000: loss 2.272607
# Iteration 6000 / 10000: loss 2.267462
# Iteration 6500 / 10000: loss 2.273079
# Iteration 7000 / 10000: loss 2.271307
# Iteration 7500 / 10000: loss 2.270455
# Iteration 8000 / 10000: loss 2.270248
# Iteration 8500 / 10000: loss 2.266985
# Iteration 9000 / 10000: loss 2.264860
# Iteration 9500 / 10000: loss 2.270046
# learning_rate: 0.000200;batch_num: 500; Accuracy: 0.392800
