# %% [markdown]
# ##### 1. 数据归一化：意义
#
# min-max归一化

# %%
import numpy as np
from data_utils import load_CIFAR10
from softmax_without_regression import Softmax
import matplotlib.pyplot as plt

# %%
def min_max_scaler(X):
    min1 = 0
    max1 = 255
    return (X-min1)/(max1-min1)

# %%
def pre_dataset():
    cifar10_dir = 'D:/dataset/cifar-10-python/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    num_train = 48000
    num_val = 2000

    mask = range(num_train, num_train + num_val)
    X_val = X_train[mask]
    y_val = y_train[mask]
    X_train = X_train[:num_train]
    y_train = y_train[:num_train]

    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))

    X_train = min_max_scaler(X_train)
    X_val = min_max_scaler(X_val)
    X_test = min_max_scaler(X_test)

    # add a parameter for W
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])

    return X_train, y_train, X_test, y_test, X_val, y_val

# %%
def get_softmax_model(X, y,learning_rate,batch_num,num_iter):
    softmax = Softmax()
    loss_history = softmax.train(X, y, learning_rate,batch_num,num_iter)
    VisualizeLoss(loss_history,num_iter)
    return softmax

def VisualizeLoss(loss_history,num_iter):
    plt.plot(loss_history)
    plt.title('num_iter: %f'%num_iter )
    plt.xlabel('Iteration number')
    plt.ylabel('Loss value')
    plt.show()

# %% [markdown]
# ##### batch_num探究：learning_rate=0.01;num_iter=2000; 变化batch_num

# %%
X_train, y_train, X_test, y_test, X_val, y_val = pre_dataset()
# Out:
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_1
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_2
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_3
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_4
# D:/dataset/cifar-10-python/cifar-10-batches-py\data_batch_5
# D:/dataset/cifar-10-python/cifar-10-batches-py\test_batch

# %%
batch_nums = [500]
learning_rate = 0.01
num_iters = [500,1000,1500,2000]
for num_iter in num_iters:
    for batch_num in batch_nums:
        softmax = get_softmax_model(X_train, y_train,learning_rate,batch_num,num_iter)
        y_pred = softmax.predict(X_test)
        acc = np.mean(y_pred == y_test)
        print('learning_rate: %f;batch_num: %d; Accuracy: %f' % (learning_rate,batch_num,acc))
# Out:
# Iteration 0 / 500, learning rate 1.000000 : loss 2.301748
# E:\2020种子班课程\计算机视觉\code\Softmax_clf\softmax_cifar10_281\softmax_without_regression.py:57: RuntimeWarning: divide by zero encountered in log
#   loss = -1 * np.sum(ground_true * np.log(pro_scores))  / num_train
# E:\2020种子班课程\计算机视觉\code\Softmax_clf\softmax_cifar10_281\softmax_without_regression.py:57: RuntimeWarning: invalid value encountered in multiply
#   loss = -1 * np.sum(ground_true * np.log(pro_scores))  / num_train
# learning_rate: 1.000000;batch_num: 500; Accuracy: 0.254700
# Iteration 0 / 500, learning rate 0.100000 : loss 2.302370
# learning_rate: 0.100000;batch_num: 500; Accuracy: 0.216600
# Iteration 0 / 500, learning rate 0.010000 : loss 2.303035
# learning_rate: 0.010000;batch_num: 500; Accuracy: 0.363600
# Iteration 0 / 500, learning rate 0.001000 : loss 2.301645
# learning_rate: 0.001000;batch_num: 500; Accuracy: 0.299700
# Iteration 0 / 500, learning rate 0.000100 : loss 2.305612
# learning_rate: 0.000100;batch_num: 500; Accuracy: 0.159400
# Iteration 0 / 500, learning rate 0.000010 : loss 2.303616
# learning_rate: 0.000010;batch_num: 500; Accuracy: 0.123600
# Iteration 0 / 500, learning rate 0.000001 : loss 2.303890
# learning_rate: 0.000001;batch_num: 500; Accuracy: 0.100300
